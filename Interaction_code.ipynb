# %%
# *Hi there*
input("What is your name?")
print(input)

print("Thank you for your time!")
print("Thanks!")
# Out:
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x105a50e30>>
# Thank you for your time!
# Thanks!
